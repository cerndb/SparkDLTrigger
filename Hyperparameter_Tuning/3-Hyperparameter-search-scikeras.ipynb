# %% [markdown]
# ## Hyperparameter search
#
# This stage performs a grid search usign Spark to find the best model for the HLF classifier. We achieve this by training multiple Keras model in parallel.
#
# To run this notebook we used the following configuration:
# * *Software stack*: Spark 3.3.2
# * *Platform*: CentOS 7, Python 3.9
# * *Spark cluster*: Analytix

# %%
# No need to run this when using CERN SWAN service
# Just add the configuration parameters for Spark on the "star" button integration

# pip install pyspark or use your favorite way to set Spark Home, here we use findspark
import findspark
findspark.init('/home/luca/Spark/spark-3.3.2-bin-hadoop3') #set path to SPARK_HOME

# Create Spark session and configure according to your environment
from pyspark.sql import SparkSession

spark = ( SparkSession.builder
          .appName("3-Hyperparameter search") \
          .master("yarn")
          .config("spark.driver.memory","4g")
          .config("spark.executor.memory","32g")
          .config("spark.executor.cores","8")
          .config("spark.executor.instances","8")
          .config("spark.dynamicAllocation.enabled", "false")
          .config("spark.sql.execution.arrow.pyspark.enabled", "true")
          .config("spark.ui.showConsoleProgress", "false")
          .getOrCreate()
        )

# %%
# Check if Spark Session has been created correctly
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pcitdbgpu1.dyndns.cern.ch:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>3-Hyperparameter search</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Load train and test datasets

# %%
# Download from https://github.com/cerndb/SparkDLTrigger/tree/master/Data
#
# For CERN users, data is already available on EOS and HDFS
# PATH = "/eos/project/s/sparkdltrigger/public/"
PATH = "hdfs://analytix/Training/Spark/TopologyClassifier/"

trainDF = spark.read.format('parquet')\
        .load(PATH + 'trainUndersampled_HLF_features.parquet')\
        .select(['HLF_input', 'encoded_label'])
        
testDF = spark.read.format('parquet')\
        .load(PATH + 'testUndersampled_HLF_features.parquet')\
        .select(['HLF_input', 'encoded_label'])

# %%
# Optionally check the number of events in the train and test datasets

test_events = testDF.count()
train_events = trainDF.count()
print('There are {} events in the train dataset'.format(train_events))
print('There are {} events in the test dataset'.format(test_events))
# Out:
# There are 3426083 events in the train dataset
# There are 856090 events in the test dataset

# %% [markdown]
# ### Take small subset of data

# %%
# Customize the fraction of data that you want to use
fraction=0.02 # 2%

trainDF_fraction = trainDF.sample(fraction=fraction, seed=42)
testDF_fraction = testDF.sample(fraction=fraction, seed=42)

# %% [markdown]
# ## Convert training and test datasets from Spark DataFrames to Numpy arrays
#
# Now we will collect and convert the Spark DataFrame into numpy arrays in order to be able to feed them to TensorFlow/Keras. We use the toPandas optimization in Spark to move data faster bewteen JVM and Python.

# %%
import numpy as np

trainPDF=trainDF_fraction.toPandas()
testPDF=testDF_fraction.toPandas()

X = np.stack(trainPDF["HLF_input"])
y = np.stack(trainPDF["encoded_label"])

X_test = np.stack(testPDF["HLF_input"])
y_test = np.stack(testPDF["encoded_label"])

# %%
trainPDF.head()
# Out:
#                                            HLF_input    encoded_label
# 0  [0.006881238128723883, 0.005688016459164144, 0...  [1.0, 0.0, 0.0]
# 1  [0.00848752162734614, 0.004737287578220116, 0....  [0.0, 0.0, 1.0]
# 2  [0.050887799422459745, 0.02019207179589794, 0....  [0.0, 1.0, 0.0]
# 3  [0.03629554161717421, 0.005379421497281561, 0....  [1.0, 0.0, 0.0]
# 4  [0.0, 0.007202983737923829, 0.0697803274453558...  [0.0, 0.0, 1.0]

# %% [markdown]
# ## Create the TF.Keras model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

def create_model(nh_1, nh_2, nh_3):
    ## Create model
    model = Sequential()
    model.add(Dense(nh_1, input_shape=(14,), activation='relu'))
    model.add(Dense(nh_2, activation='relu'))
    model.add(Dense(nh_3, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    
    ## Compile model
    optimizer = 'Adam'
    loss = 'categorical_crossentropy'
    model.compile(loss=loss, optimizer=optimizer, metrics=["accuracy"])
    
    return model

# %% [markdown]
# ## Test baseline model

# %%
baseline = create_model(50,20,10)

# %time history = baseline.fit(X, y, batch_size=128, epochs=50, validation_data=(X_test, y_test), verbose=0)
# Out:
# CPU times: user 1min 22s, sys: 6.9 s, total: 1min 29s
# Wall time: 56.6 s

# %%
import matplotlib.pyplot as plt 

# Graph with loss vs. epoch
# %matplotlib notebook
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
# Graph with accuracy vs. epoch
# %matplotlib notebook
plt.figure()
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(loc='lower right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred=history.model.predict(X_test)
y_true=y_test
# Out:
# 541/541 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import accuracy_score

print('Accuracy of the HLF classifier: {:.4f}'.format(
    accuracy_score(np.argmax(y_true, axis=1),np.argmax(y_pred, axis=1))))
# Out:
# Accuracy of the HLF classifier: 0.9040

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
labels_name = ['qcd', 'tt', 'wjets']
labels = [0,1,2]

cm = confusion_matrix(np.argmax(y_true, axis=1), np.argmax(y_pred, axis=1), labels=labels)

## Normalize CM
cm = cm / cm.astype(np.float).sum(axis=1)

fig, ax = plt.subplots()
ax = sns.heatmap(cm, annot=True, fmt='g')
ax.xaxis.set_ticklabels(labels_name)
ax.yaxis.set_ticklabels(labels_name)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /tmp/luca/ipykernel_12967/950292951.py:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cm = cm / cm.astype(np.float).sum(axis=1)
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Create the Keras classifier
#
# Wrapping our keras model into a Sklearn classifier allows us to use Sklearn grid Search. We will the distribute the grid search across executors usign Spark-Sklearn.

# %%
# originally this used from tensorflow.keras.wrappers.scikit_learn import KerasClassifier, now depreacated
# !pip install scikeras
from scikeras.wrappers import KerasClassifier

model = KerasClassifier(build_fn=create_model, nh_1=None, nh_2=None, nh_3=None, loss="categorical_crossentropy")

# %%
model.get_params().keys()
# Out:
# dict_keys(['model', 'build_fn', 'warm_start', 'random_state', 'optimizer', 'loss', 'metrics', 'batch_size', 'validation_batch_size', 'verbose', 'callbacks', 'validation_split', 'shuffle', 'run_eagerly', 'epochs', 'nh_1', 'nh_2', 'nh_3', 'class_weight'])

# %% [markdown]
# ## Define the grid parameters

# %%
batch_size = [64, 100, 200]
epochs = [10, 30, 50]

## Number of hidden units per layer
nh_1 = [50,100,150]
nh_2 = [20,50,100]
nh_3 = [10,20,50]

# %%
param_grid = {'batch_size':batch_size,
              'epochs':epochs,
              'nh_1':nh_1, 'nh_2':nh_2, 'nh_3':nh_3}

# %% [markdown]
# ## Grid Search with Spark
# Spark is used to parallelize grid search.

# %%
# This uses joblibspark, originally it was written with spark_sklearn.grid_search now deprecated
# !pip install joblibspark 
from joblibspark import register_spark

register_spark() # register spark backend

# %%
from sklearn.utils import parallel_backend
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, verbose=1)
# Note, for random grid search search use:
# grid = GridSearchCV(sc, estimator=model, param_grid=random_param_grid, cv=5, verbose=1)

with parallel_backend('spark', n_jobs = 40):
    # %time gridSearch_result = grid.fit(X, y)
# Out:
# 23/03/10 16:39:58 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# /afs/cern.ch/work/c/canali/public/anaconda202111/lib/python3.9/site-packages/scikeras/wrappers.py:301: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   warnings.warn(
# Epoch 1/50
# 1080/1080 [==============================] - 4s 2ms/step - loss: 0.4181 - accuracy: 0.8457
# Epoch 2/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.3302 - accuracy: 0.8786
# Epoch 3/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.3011 - accuracy: 0.8907
# Epoch 4/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2863 - accuracy: 0.8965
# Epoch 5/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2801 - accuracy: 0.8980
# Epoch 6/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2753 - accuracy: 0.8989
# Epoch 7/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2727 - accuracy: 0.9009
# Epoch 8/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2699 - accuracy: 0.9022
# Epoch 9/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2672 - accuracy: 0.9022
# Epoch 10/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2654 - accuracy: 0.9033
# Epoch 11/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2622 - accuracy: 0.9043
# Epoch 12/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2602 - accuracy: 0.9051
# Epoch 13/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2597 - accuracy: 0.9053
# Epoch 14/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2569 - accuracy: 0.9055
# Epoch 15/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2560 - accuracy: 0.9063
# Epoch 16/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2545 - accuracy: 0.9069
# Epoch 17/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2533 - accuracy: 0.9073
# Epoch 18/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2512 - accuracy: 0.9070
# Epoch 19/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2520 - accuracy: 0.9077
# Epoch 20/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2495 - accuracy: 0.9084
# Epoch 21/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2479 - accuracy: 0.9089
# Epoch 22/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2475 - accuracy: 0.9086
# Epoch 23/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2460 - accuracy: 0.9093
# Epoch 24/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2445 - accuracy: 0.9108
# Epoch 25/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2439 - accuracy: 0.9109
# Epoch 26/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2424 - accuracy: 0.9108
# Epoch 27/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2420 - accuracy: 0.9114
# Epoch 28/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2425 - accuracy: 0.9107
# Epoch 29/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2410 - accuracy: 0.9120
# Epoch 30/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2401 - accuracy: 0.9115
# Epoch 31/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2393 - accuracy: 0.9117
# Epoch 32/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2386 - accuracy: 0.9124
# Epoch 33/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2371 - accuracy: 0.9128
# Epoch 34/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2376 - accuracy: 0.9130
# Epoch 35/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2362 - accuracy: 0.9130
# Epoch 36/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2361 - accuracy: 0.9137
# Epoch 37/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2347 - accuracy: 0.9141
# Epoch 38/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2360 - accuracy: 0.9139
# Epoch 39/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2341 - accuracy: 0.9141
# Epoch 40/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2350 - accuracy: 0.9133
# Epoch 41/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2336 - accuracy: 0.9148
# Epoch 42/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2334 - accuracy: 0.9136
# Epoch 43/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2331 - accuracy: 0.9142
# Epoch 44/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2328 - accuracy: 0.9149
# Epoch 45/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2325 - accuracy: 0.9148
# Epoch 46/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2309 - accuracy: 0.9158
# Epoch 47/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2317 - accuracy: 0.9140
# Epoch 48/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2302 - accuracy: 0.9157
# Epoch 49/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2296 - accuracy: 0.9162
# Epoch 50/50
# 1080/1080 [==============================] - 2s 2ms/step - loss: 0.2298 - accuracy: 0.9160
# CPU times: user 2min 46s, sys: 24.8 s, total: 3min 11s
# Wall time: 26min 2s

# %%
# Get the parameters giving the best result
gridSearch_result.best_estimator_.get_params()
# Out:
# {'model': None,
#  'build_fn': <function __main__.create_model(nh_1, nh_2, nh_3)>,
#  'warm_start': False,
#  'random_state': None,
#  'optimizer': 'rmsprop',
#  'loss': 'categorical_crossentropy',
#  'metrics': None,
#  'batch_size': 64,
#  'validation_batch_size': None,
#  'verbose': 1,
#  'callbacks': None,
#  'validation_split': 0.0,
#  'shuffle': True,
#  'run_eagerly': False,
#  'epochs': 50,
#  'nh_1': 150,
#  'nh_2': 20,
#  'nh_3': 20,
#  'class_weight': None}

# %%
# See the performance on the test dataset 
y_pred = gridSearch_result.best_estimator_.predict_proba(X_test)
# Out:
# 271/271 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import roc_curve, auc

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
# Dictionary containign ROC-AUC for the three classes 
roc_auc
# Out:
# {0: 0.9845105544553965, 1: 0.9828810013060272, 2: 0.9772392214596825}

# %%
# %matplotlib notebook

# Plot roc curve 
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')


plt.figure()
plt.plot(fpr[0], tpr[0], lw=2, 
         label='HLF classifier (AUC) = %0.4f' % roc_auc[0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Background Contamination (FPR)')
plt.ylabel('Signal Efficiency (TPR)')
plt.title('$tt$ selector')
plt.legend(loc="lower right")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
spark.stop()
